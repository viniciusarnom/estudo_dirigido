# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciusarnom/estudo_dirigido/blob/main/Ler%20Arquivo%20no%20futuro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Como ler o ficheiro gerado:
dados_lidos = np.fromfile('features_WiFi_Day_1_bes_s1_saida.bin', dtype=np.float32)

# Recuperar o formato de 5 colunas:
dados_reconstruidos = dados_lidos.reshape(-1, 5)

print("Formato dos dados reconstruídos:", dados_reconstruidos.shape)
